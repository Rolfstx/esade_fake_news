# %% [markdown]
# Code used from this link:
#
# https://medium.com/technonerds/using-fastais-ulmfit-to-make-a-state-of-the-art-multi-label-text-classifier-bf54e2943e83
#
# GitHub Link:
# https://github.com/aditya10/ULMFiT-fastai-text-classifier/blob/master/ULMFiT_tutorial.ipynb

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from fastai.text import *
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split

# %% [markdown]
# ###Model set-up

# %%
# %cd "gdrive/My Drive/Colab Notebooks"
# !ls
# Out:
# /content/gdrive/My Drive/Colab Notebooks
# 20200504-193926_joe_biden_nlp.csv	Language_model.ipynb  nlp_EDA.ipynb
# 20200504-193926_joe_biden_nlp_subs.csv	model_language.ipynb  nlp_EDA_v2.ipynb
# Extract_subtitles.ipynb			models		      nlp_export.pkl

# %%
# load train_cleaned.csv

filename = "20200504-193926_joe_biden_nlp_subs.csv"
train_language = pd.read_csv(filename, index_col=0)

# %%
train_language.head()
# Out:
#    Bias_num  ...                                          subtitles
# 0         0  ...  ["who hasn't been shocked by a recent electric...
# 1         0  ...  ["you're one of the greatest con men of all ti...
# 2         0  ...  ["if you thought the insults hold between Nort...
# 3         0  ...  ["bravery courage defiance heartbreak they're ...
# 4         0  ...                                                NaN
#
# [5 rows x 6 columns]

# %%
#combine columns. Fastai only works with 1 text column
#train_language['text'] = train_language['title'] + " " + train_language['description']

# %%
#drop columns that will not be used.
train_language.drop(['title', 'description', 'channel', 'id'], inplace=True, axis=1)

# %%
#check for NAs
train_language.isna().sum()
# Out:
# Bias_num       0
# subtitles    112
# dtype: int64

# %%
#drop NAs
train_language.dropna(inplace=True)

# %%
#make sure no NAs
train_language.isna().sum()
# Out:
# Bias_num     0
# subtitles    0
# dtype: int64

# %%
#length of dataframe
len(train_language)
# Out:
# 743

# %%
train_language.head()
# Out:
#    Bias_num                                          subtitles
# 0         0  ["who hasn't been shocked by a recent electric...
# 1         0  ["you're one of the greatest con men of all ti...
# 2         0  ["if you thought the insults hold between Nort...
# 3         0  ["bravery courage defiance heartbreak they're ...
# 5         0  ["Jeffrey Epstein was a billionaire New York b...

# %%
#create train and test split
df_trn, df_val = train_test_split(train_language, stratify = train_language['Bias_num'], test_size = 0.3, random_state=42)
df_trn.shape, df_val.shape
# Out:
# ((520, 2), (223, 2))

# %% [markdown]
# ###Pre-processing language model

# %%
# Language model data
data_lm = TextLMDataBunch.from_df(train_df = df_trn, valid_df = df_val, path = "")

# %%
# Classifier model data
data_clas = TextClasDataBunch.from_df(train_df = df_trn, valid_df = df_val, path = "", vocab=data_lm.train_ds.vocab, bs=32)

# %%
# check out data
data_clas.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos [ " [ xxmaj music ] hello world on this week 's episode of the concrete podcast we 're back with everyone 's favorite conman xxmaj matthew b xxmaj cox this podcast tells the story of a kid in his mid-20s named xxmaj blaine xxmaj davis who managed to steal tens of millions of dollars utilizing foreign exchange market trading otherwise known as xxmaj forex xxmaj blaine was so</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>xxbos [ " we 're back round two of the xxmaj matthew xxmaj cox story saga series podcast series we had such an overwhelming performance here so where did we leave off on the first podcast i think we wrapped got arrested yeah you got arrested the very end of your career in mortgage fraud and identity theft right you got busted from that stupid home invasion you went to</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>xxbos [ " [ xxmaj music ] we are back on the podcast today with xxmaj matthew xxmaj cox how you doing you 're well known for making over twelve million dollars through mortgage fraud were sentenced to 26 years in prison and now you 're a true crime author right so that 's that nail it pretty well yeah that 's pretty good okay you also have the xxmaj</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>xxbos [ " [ xxmaj music ] all right world here we go jordan peterson ben shapiro dave rubin we got a lot to do we got about two hours to do it i thought how am i gon na start this thing i could ask you guys how you 're doing we could dive right into some deep topics but then i thought no let 's do something else</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>xxbos [ ' &gt; &gt; i ’m xxmaj jeff xxmaj bezos . &gt; &gt; xxmaj what is your claim to fame ? &gt; &gt; i ’m the founder of xxmaj amazon.com . &gt; &gt; xxup narrator : xxmaj from the award - winning producers of “ xxmaj the \n  xxmaj facebook xxmaj dilemma ” . &gt; &gt; xxmaj richest guy in the world . &gt; &gt; xxup narrator :</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %%
#data_clas.save("/content/gdrive/My Drive/language_models/databunch/TextClasDataBunch.pkl")

# %%
#data_lm.save("/content/gdrive/My Drive/language_models/databunch/TextLMDataBunch.pkl")

# %% [markdown]
# ### Language model

# %%
# train language model
learn = language_model_learner(data_lm, AWD_LSTM, drop_mult=0.3)
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-modelzoo/wt103-fwd.tgz

# %%
# find the optimal learning rate to train our language model on
#learn.lr_find()
#learn.recorder.plot(suggestion=True)
#min_grad_lr = learn.recorder.min_grad_lr

# %% [markdown]
# Probability to predict next word correctly stands at 50%. That's pretty good.

# %%
# let’s use this learning rate to train the language model
learn.fit_one_cycle(10, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.722639</td>
#       <td>4.430247</td>
#       <td>0.265535</td>
#       <td>02:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.322756</td>
#       <td>4.080153</td>
#       <td>0.290675</td>
#       <td>02:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.279948</td>
#       <td>3.963644</td>
#       <td>0.300366</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.104319</td>
#       <td>3.918147</td>
#       <td>0.304159</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.016930</td>
#       <td>3.894213</td>
#       <td>0.305743</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.917613</td>
#       <td>3.883042</td>
#       <td>0.307359</td>
#       <td>03:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.882535</td>
#       <td>3.875439</td>
#       <td>0.307931</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.883436</td>
#       <td>3.872663</td>
#       <td>0.308124</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.871031</td>
#       <td>3.871629</td>
#       <td>0.308366</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.846335</td>
#       <td>3.871323</td>
#       <td>0.308390</td>
#       <td>03:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Unfreezing all layers increases accuracy of predicting the next word correctly to 62%, which is insanely good.

# %%
# unfreezing weights and training the rest of the NN
learn.unfreeze()
learn.fit_one_cycle(2, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.779069</td>
#       <td>3.747912</td>
#       <td>0.323905</td>
#       <td>03:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.516795</td>
#       <td>3.681820</td>
#       <td>0.333766</td>
#       <td>03:36</td>
#     </tr>
#   </tbody>
# </table>

# %%
#save the language model encoder so that we can load it later in our classifier
learn.save_encoder("ft_enc")

# %% [markdown]
# ### Language classifier

# %%
#set-up classifier
learn = text_classifier_learner(data_clas, AWD_LSTM, drop_mult=0.5, metrics=[accuracy])
learn.load_encoder('ft_enc')

# %%
#train classifier for 10 epochs
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.651836</td>
#       <td>0.697413</td>
#       <td>0.475336</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.584721</td>
#       <td>0.684497</td>
#       <td>0.569507</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.529015</td>
#       <td>0.591447</td>
#       <td>0.717489</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.490352</td>
#       <td>0.501408</td>
#       <td>0.744395</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.459920</td>
#       <td>0.511727</td>
#       <td>0.744395</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.414801</td>
#       <td>0.509740</td>
#       <td>0.739910</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.372712</td>
#       <td>0.471851</td>
#       <td>0.784753</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.340312</td>
#       <td>0.476839</td>
#       <td>0.780269</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.309512</td>
#       <td>0.491057</td>
#       <td>0.766816</td>
#       <td>01:37</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.287107</td>
#       <td>0.488639</td>
#       <td>0.766816</td>
#       <td>01:34</td>
#     </tr>
#   </tbody>
# </table>

# %%
#save model weights
learn.save('language_classifier')

# %%
#inspect losses.
learn.recorder.plot_losses()

# %%
# unfreezing weights and training the rest of the NN
learn.freeze_to(-2)
learn.fit_one_cycle(4, slice(5e-3, 2e-3), moms=(0.8,0.7))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.267671</td>
#       <td>0.566065</td>
#       <td>0.753363</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.296154</td>
#       <td>0.473213</td>
#       <td>0.762332</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.264140</td>
#       <td>0.444678</td>
#       <td>0.775785</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.232135</td>
#       <td>0.416155</td>
#       <td>0.798206</td>
#       <td>01:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
#export language classifier for prediction
learn.export(file = "nlp_export.pkl")

# %% [markdown]
# ###Confusion matrix

# %%
# create confusion matrix
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)
interp.plot_confusion_matrix()

# %%
train_language['Bias_num'].sum()/len(train_language)
# Out:
# 0.32570659488559894
