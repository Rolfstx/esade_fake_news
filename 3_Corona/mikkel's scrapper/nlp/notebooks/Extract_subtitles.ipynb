# %%
# %pip install youtube_transcript_api
# Out:
# Requirement already satisfied: youtube_transcript_api in c:\programdata\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from youtube_transcript_api) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->youtube_transcript_api) (2019.6.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd "gdrive/My Drive/Colab Notebooks"
# !ls
# Out:
# /content/gdrive/My Drive/Colab Notebooks
# 20200504-193926_joe_biden_nlp.csv  model_language.ipynb  nlp_EDA_v2.ipynb
# Extract_subtitles.ipynb		   models		 nlp_export.pkl
# Language_model.ipynb		   nlp_EDA.ipynb

# %%
import pandas as pd
import numpy as np
from youtube_transcript_api import YouTubeTranscriptApi
from tqdm import tqdm

# %%
df = pd.read_csv("C:/Users/asf/Documents/GitHub/esade_fake_news/3_Corona/mikkel's scrapper/nlp/Black_Lives_nlp_data.csv", index_col=0)
df.head()
# Out:
#    binary                                              title  \
# 1       1  Washington protests: Demonstrations escalate o...
# 2       0  A mind-expanding tour of the cosmos with Neil ...
# 3       0  Neil DeGrasse Tyson: Blackholes and Other Cosm...
# 4       0  Science and Communication: Alan Alda in Conver...
# 5       0    Bob Woodward’s "FEAR: Trump in The White House"
#
#                                          description        channel  \
# 1  Police have used force to push protesters back...         9 News
# 2  Your support helps us keep our content free fo...  92nd Street Y
# 3  Your support helps us keep our content free fo...  92nd Street Y
# 4  What does it mean to be a true communicator? T...  92nd Street Y
# 5  Watergate journalist Bob Woodward’s new book, ...  92nd Street Y
#
#             id
# 1  JG0N6b9EPJw
# 2  AyAK3QBnMGQ
# 3  rYzBxo3hbYQ
# 4  syIb73RQqVU
# 5  UkrBSUp55Xk

# %%
tttt = []

with tqdm(total=len(df['id'])) as pbar:  
    for idx in df['id']:
        try:
            t = YouTubeTranscriptApi.get_transcript(idx)
        except:
            tttt.append([idx, np.nan])
            continue
        tt = [i["text"] for i in t]
        ttt = [' '.join(tt)]
        tttt.append([idx, ttt])
        pbar.update(1)

df_sub = pd.DataFrame(tttt, columns=['video_id', 'subtitles'])
df_sub.head()
# Out:
#  84%|████████▍ | 751/896 [12:20<02:45,  1.14s/it]
#       video_id                                          subtitles
# 0  JG0N6b9EPJw                                                NaN
# 1  AyAK3QBnMGQ  [that's welcome the Oh deGrasse Tyson alright ...
# 2  rYzBxo3hbYQ                                                NaN
# 3  syIb73RQqVU  [I just wanted to comment that this illustrati...
# 4  UkrBSUp55Xk  [um I thought I'd start Bob it's it's an honor...

# %%
df_sub.isna().sum()
# Out:
# video_id       0
# subtitles    145
# dtype: int64

# %%
df_sub[df_sub['subtitles'].isna()]
# Out:
#         video_id subtitles
# 0    JG0N6b9EPJw       NaN
# 2    rYzBxo3hbYQ       NaN
# 7    ZGeAGDCCd1k       NaN
# 10   w_Ma8oQLmSM       NaN
# 11   l-C8ynIcABo       NaN
# 12   1jGkF0-qcCg       NaN
# 13   OE7YAtHremg       NaN
# 56   0euVSmfVcWc       NaN
# 58   Z-u-rzRAaWk       NaN
# 59   HIk_SxVemo0       NaN
# 60   wseW9hhI36U       NaN
# 61   t-axd1Ht_J8       NaN
# 67   TmNSlF7lcaw       NaN
# 68   j20o1mbixgc       NaN
# 69   tOHUwwP6LLs       NaN
# 70   fjdlJBSp1lc       NaN
# 71   SPN-YJRaOl4       NaN
# 116  n6cQi1fB5c8       NaN
# 127  zM5Ljm87V3U       NaN
# 133  ghCOVjAILxo       NaN
# 144  UI5teFbIXXI       NaN
# 172  -avpx8UTakI       NaN
# 182  WjmDwWUhEpg       NaN
# 187  _MG6J2z2dVE       NaN
# 224  2F2qyquKsJs       NaN
# 235  Dl3GGCwHeSM       NaN
# 236  lpPYCsljjc8       NaN
# 237  sxTavjEu8Yc       NaN
# 238  HEGC2MjaWAM       NaN
# 245  0NeuAFz7NFk       NaN
# ..           ...       ...
# 791  EJLEojr0-O8       NaN
# 792  GA4Kfoa5C0c       NaN
# 795  yP7pebZpLw0       NaN
# 803  Axa9fTKqcMw       NaN
# 818  rfq0Yw2sMq0       NaN
# 819  y6Q1qqMp5_o       NaN
# 823  ZP0L1uWzKG4       NaN
# 824  fDKEetDkwWM       NaN
# 825  ewPburLEZyY       NaN
# 826  aSIUSBnkSc4       NaN
# 827  aN5e0XyliOk       NaN
# 828  YSYx7eVPnEA       NaN
# 830  FyYi-y68eKw       NaN
# 831  b7XVPmc8Sew       NaN
# 832  rFGE3X6Yhj0       NaN
# 834  ubG_UbxfyJg       NaN
# 836  I-gLu2ybr_Y       NaN
# 837  6ycQMXrcE2c       NaN
# 841  SVeuJpqCG28       NaN
# 845  pvR9YN8Mpgc       NaN
# 846  U8q2IEj-j24       NaN
# 847  MIjYNN8HOK4       NaN
# 849  d4xUfJKA7RA       NaN
# 860  oXWeP8TrIvU       NaN
# 862  UrKwTVW4iS0       NaN
# 863  loXzKugJiuo       NaN
# 866  An4vgjvMZWQ       NaN
# 880  pttHSJCl4Ks       NaN
# 884  IrCQh1usdzE       NaN
# 894  ck1kQA3CUfc       NaN
#
# [145 rows x 2 columns]

# %%
df2 = df.merge(df_sub, left_on='id', right_on='video_id')

# %%
#i checked a few nan subtitles and they don't have subtitles. 
df2[df2['subtitles'].isna()].head()
# Out:
#     binary                                              title  \
# 0        1  Washington protests: Demonstrations escalate o...
# 2        0  Neil DeGrasse Tyson: Blackholes and Other Cosm...
# 7        0  Pence meets with black pastors, refuses to ack...
# 10       0  Watch the Latest News Headlines and Live Event...
# 11       0  Police monitor George Floyd protests in San Fr...
#
#                                           description        channel  \
# 0   Police have used force to push protesters back...         9 News
# 2   Your support helps us keep our content free fo...  92nd Street Y
# 7   The mayor of Tulsa prepared for a “civil emerg...       ABC News
# 10  #georgefloyd #georgefloydprotests #minneapolis...       ABC News
# 11  Despite the new curfew order, crowds are still...       ABC News
#
#              id     video_id subtitles
# 0   JG0N6b9EPJw  JG0N6b9EPJw       NaN
# 2   rYzBxo3hbYQ  rYzBxo3hbYQ       NaN
# 7   ZGeAGDCCd1k  ZGeAGDCCd1k       NaN
# 10  w_Ma8oQLmSM  w_Ma8oQLmSM       NaN
# 11  l-C8ynIcABo  l-C8ynIcABo       NaN

# %%
df2.drop('video_id', inplace=True, axis=1)

# %%
df2.to_csv("black_lives_nlp_subs_1.csv")

# %%
df2
# Out:
#      binary                                              title  \
# 0         1  Washington protests: Demonstrations escalate o...
# 1         0  A mind-expanding tour of the cosmos with Neil ...
# 2         0  Neil DeGrasse Tyson: Blackholes and Other Cosm...
# 3         0  Science and Communication: Alan Alda in Conver...
# 4         0    Bob Woodward’s "FEAR: Trump in The White House"
# 5         0  Dr. Neil deGrasse Tyson: Pluto's Place in the ...
# 6         0  Christopher Hitchens and Tariq Ramadan Debate:...
# 7         0  Pence meets with black pastors, refuses to ack...
# 8         0  Trump rally comes against backdrop of racial p...
# 9         0  Oklahoma state legislator reacts to Trump rall...
# 10        0  Watch the Latest News Headlines and Live Event...
# 11        0  Police monitor George Floyd protests in San Fr...
# 12        0  Peaceful rally at Oakland tech moves to city s...
# 13        0  John Bolton believes Putin thinks he can play ...
# 14        0    Trevor Noah's Mom Doesn't Care He's a Celebrity
# 15        0                         Can You Name This Country?
# 16        0                 People Apologize to Their Teachers
# 17        0                            Can You Name a Country?
# 18        0       PROOF: The World is Laughing at Donald Trump
# 19        0  Woman on quest to find sperm donor father find...
# 20        0                     Seed of Doubt l 20/20 l PART 1
# 21        0                     Seed of Doubt l 20/20 l PART 2
# 22        0                     Seed of Doubt l 20/20 l PART 3
# 23        0                  20/20 - Your Biggest Fan - Part 1
# 24        0                  The Woman in the Suitcase: Part 1
# 25        0  20/20 Mar 29 Pt 1: Janet Christiansen and Rave...
# 26        0                         My Father BTK - 20/20 PT 1
# 27        0             Undercover Girlfriend l 20/20 l PART 1
# 28        0  Adults abandoned at birth turn to genetic gene...
# 29        0                  20/20 - Your Biggest Fan - Part 2
# ..      ...                                                ...
# 866       0  I'm part of Windrush and am returning to Jamai...
# 867       0  Hit and run suspect requests bond for Christma...
# 868       0  Ridiculous Jobs Queen Elizabeth Actually Has H...
# 869       1  Douglas Murray on the death of Europe & identi...
# 870       1  Disgruntled builder demolishes street over "un...
# 871       0  "Don't Lose Your Accent / Learning Accents" - ...
# 872       0  "Emojis & Selfies: Cellphones Are Robbing Us" ...
# 873       0    The NRA For Black People Wants to Get Political
# 874       0                  SHELTER (Full Length Documentary)
# 875       0                     The Arranged Gay Marriage Scam
# 876       0  The Land of No Men: Inside Kenya's Women-Only ...
# 877       0      Inside Brazil's Biggest Prison Beauty Pageant
# 878       0    Inside The Fight Against Online Child Sex Abuse
# 879       0  Why Women Are Quitting Their Side Hustle: Leav...
# 19   v5h1jhMv-2I  [[Music] my name is Eve Wiley I live in Dallas...
# 20   mT6-JjluNTA  [[Music] my name is Eve Wiley I live in Dallas...
# 21   d8Wr7Oyjb-w  [[Music] when couples have fertility issues ve...
# 22   LonVmFkZH0A  [Oh [Music] Eve who was just so excited to kno...
# 23   rDzGCN5Qh-M  [one of the most interesting aspects of Hollyw...
# 24   7yZhWcQF6e8  [right now the temperatures as cool as homeste...
# 25   kRpJQCp55-0  [[Music] so this is a typical college love sto...
# 26   6ggPe5jT9_4  [[Applause] [Music] I'm walking on the street ...
# 27   nYuKk1xR99w  [[Music] champaign-urbana is in the heart of C...
# 28   y8LYR6KK5K0  [Who am I where am i from I was abandoned at a...
# 29   s3zbU4aNQNQ  [[Music] Pam Dawber by the mid 80s was a house...
# ..           ...                                                ...
# 866  An4vgjvMZWQ                                                NaN
# 867  vcTgT2ZW5u0  [this is a bond hearing on the day of her arre...
# 868  c-6LSua_y0I  [Queen Elizabeth II employs an astonishing\n1,...
# 869  QKQGDZ2MJow  [imagine if the gay rights movement has said w...
# 870  YdbAamS67bQ  [a row of new homes now lies in ruin allegedly...
# 871  MhCEdIqFCck  [The newspapers say that, he’s famous. So now ...
# 872  2r3qk7ifgI4  [Some of you may or may not\nknow I have a new...
# 873  GsTAkqWaI8A  [[Applause] you're gonna hit flour out and the...
# 874  KUfNbNBFwRI  [what is your problem she's a minor listen lis...
# 875  FyeYvsFv7pM  [I think umm, Urvi is a\nhorrific human being....
# 876  UrnmBLB-UX4  [- I'm trying to do like, a 2-foot skank,\nand...
# 877  3f-kl9l0bDw  [[Bianca Zanini]: Brazil is know international...
# 878  xcCj1zNpKoM  [[Laughter] [Music] we're at an undisclosed lo...
# 879  L6eujSJ0-RU  [[Music] lularoe made me feel so good about me...
# 880  pttHSJCl4Ks                                                NaN
# 881  WBMcoJWo92Y  [Have you ever been called a leftover woman? Y...
# 882  bqPARIKHbN8  [You two are down here. The Shed is the number...
# 883  gwqwRa8Mj-c  [well he's not even moving get off of the leg ...
# 884  IrCQh1usdzE                                                NaN
# 885  PYd9gd6sNMY  [[Music] we're here in cumulus Sun square you ...
# 886  24R8JObNNQ4  [[SPEAKING KOREAN] [KOREAN PATRIOTIC SONG] SHA...
# 887  lJFqvRwOiis  [You crossed. Take your camera and point it ac...
# 888  MQyxG4vTyZ8  [This is me in the middle of crossing one\nof ...
# 889  6_RdnVtfZPY  [The people of Hong Kong are out in the street...
# 890  r5Ps1TZXAN8  [This is the Golden Temple. People come here f...
# 891  qBfyIQbxXPs  [It's graduation day at a children's\nschool i...
# 892  luTPMHC7zHY  [This is Fiery Cross island. It's a little mor...
# 893  Z-HvpKCMe5U  [welcome to the stage Dan Harmon Joel McHale J...
# 894  ck1kQA3CUfc                                                NaN
# 895  TqKEUv82j0c  [it's really hard to look back because that no...
#
# [896 rows x 6 columns]
