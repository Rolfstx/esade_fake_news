# %% [markdown]
# # Json to CSV and TOP 25

# %% [markdown]
# ### Coronavirus is a Hoax Search:

# %%
import json
import pandas as pd

with open("C:/Users/asf/Documents/GitHub/esade_fake_news/3_Corona/mikkel's scrapper/data/videos/20200503-184010_coronavirus_is_a_haux.json") as json_file:
    data = json.load(json_file)

# %%
ids = [list(d.keys())[0] for d in data]
flat_data = []
for unique_id in ids:
    flat = dict(data[ids.index(unique_id)][unique_id])
    flat['id'] = unique_id
    flat['recommendations'] = len(flat['recommendations'])
    flat_data.append(flat)
flat_data = pd.DataFrame(flat_data)

# %%
total_vids = len(flat_data)
total_vids
# Out:
# 680

# %%
top25 = flat_data[['title','id','channel','genre','key']].groupby(['title','channel','genre','id']).count().sort_values(by='key',ascending=False).head(25)

# %%
# export Data.Frame
top25.to_csv("C:/Users/asf/Documents/GitHub/esade_fake_news/3_Corona/mikkel's scrapper/data/top25/20200503-184010_coronavirus_is_a_haux_top25.csv", header=True)

# %%
top25
# Out:
#                                                                                                                 key
# title                                              channel                         genre           id
# Coronavirus outbreak: NY Governor Cuomo provide... Global News                     News & Politics ZQYAElmOXEI   34
# LIVE: New York Governor Cuomo delivers update o... Yahoo Finance                   News & Politics 4cGK-iQRrTk   28
# Live: New York Governor Cuomo Holds Coronavirus... NBC News                        News & Politics P0UaGdFvN7Q   25
# New York Gov. Cuomo Delivers COVID-19 Update | ... NowThis News                    News & Politics wwOGS9fLbKw   21
# Coronavirus: New York governor Andrew Cuomo hol... Guardian News                   News & Politics SczCxUdMzPo   20
# Tri-State area governors make joint announcemen... Eyewitness News ABC7NY          News & Politics LBFwWgdsJP4   16
# 'The Dangerous Case Of Donald Trump': 27 Psychi... MSNBC                           News & Politics 6nhoGIvOKJU    9
# PM Justin Trudeau and federal ministers address... Global News                     News & Politics r4RUTHwCfZw    9
# Cuomo Updates on NY Coronavirus Response           NBC New York                    News & Politics IsJ6_5ru8A0    8
# Psychiatrist On ‘The Essential Emptiness Of Pre... MSNBC                           News & Politics 0B4nS1-ScYw    7
# Jordan Klepper vs. Trump Supporters | The Daily... The Daily Show with Trevor Noah Comedy          NzDhm808oU4    7
# Frank Abagnale: "Catch Me If You Can" | Talks a... Talks at Google                 People & Blogs  vsMydMDi3rI    7
# Trump Talk: All Our Best Mashups In One Video      VICE News                       News & Politics 2i4JxWkSYzU    7
# All about Donald Trump’s early years, from trou... PBS NewsHour                    News & Politics rFGE3X6Yhj0    7
# Trump’s Coronavirus Address, Blooper Reel Inclu... The Daily Show with Trevor Noah Comedy          BWO6i8cH8SA    7
# Full Interview: Edward Snowden On Trump, Privac... MSNBC                           News & Politics e9yK1QndJSM    6
# "HEARING IS A JOKE" Democrats MELTDOWN During M... FOX 10 Phoenix                  News & Politics OKifiMcnnek    6
# Live: Michael Gove leads coronavirus daily brie... The Telegraph                   News & Politics f5zukRrgPhk    6
# Joe Rogan Experience #1368 - Edward Snowden        PowerfulJRE                     People & Blogs  efs3QRr8LWw    6
# Psychiatrist On Trump’s ‘Dangerous’ Response To... MSNBC                           News & Politics AKgq0rnIR7g    5
# Watch CNBC's full interview with Berkshire Hath... CNBC Television                 News & Politics JvEas_zZ4fM    5
# Diana: The Royal Truth                             YouTube Movies                  Movies          ri8YBB5v878    5
# Requiem for the American Dream                     YouTube Movies                  Movies          hZnuc-Fv_Tc    5
# Top psychiatrist: Trump's 'mental impairment' p... FRANCE 24 English               News & Politics ghg4-1rEZzk    5
# COVID-19 update: Trudeau addresses Canadians | ... CBC News                        News & Politics QjCtIWEimTk    5

# %%
#top25 videos weight
top25['key'].sum() / len(flat_data)
# Out:
# 0.3911764705882353

# %%
#top25 average - number of videos per unique video
top25['key'].sum() / 25
# Out:
# 10.64

# %%
top25_channel = flat_data[['channel','key']].groupby(['channel']).count().sort_values(by='key',ascending=False).head(25)

# %%
top25_channel
# Out:
#                                  key
# channel
# Global News                       47
# The Daily Show with Trevor Noah   46
# MSNBC                             42
# NBC News                          32
# Yahoo Finance                     28
# Fox News                          25
# PowerfulJRE                       24
# YouTube Movies                    22
# NowThis News                      21
# Guardian News                     20
# PBS NewsHour                      17
# LastWeekTonight                   16
# Eyewitness News ABC7NY            16
# CBS News                          11
# FRONTLINE PBS | Official          11
# CNBC Television                   11
# DW Documentary                    11
# thechesswebsite                   11
# FRANCE 24 English                  8
# CNN                                8
# NBC New York                       8
# VICE News                          7
# The Telegraph                      7
# Talks at Google                    7
# FOX 10 Phoenix                     7

# %%
#top25_channel channel weight
top25_channel['key'].sum() / len(flat_data)
# Out:
# 0.6808823529411765

# %%
#top25 average - number of videos per unique video
top25_channel['key'].sum() / 25
# Out:
# 18.52

# %%
#top25 by genre
top25_genre = flat_data[['genre','key']].groupby(['genre']).count().sort_values(by='key',ascending=False).head(25)

# %%
top25_genre
# Out:
#                        key
# genre
# News & Politics        408
# Entertainment           59
# Comedy                  55
# Education               54
# People & Blogs          48
# Movies                  22
# Science & Technology    16
# Nonprofits & Activism    7
# Music                    4
# Sports                   3
# Travel & Events          2
# Film & Animation         1
# Howto & Style            1

# %%
#top25_genre genre weight
top25_genre['key'].sum() / len(flat_data)
# Out:
# 1.0

# %% [markdown]
# ### Coronavirus Search:

# %%
import json
import pandas as pd

with open("C:/Users/asf/Documents/GitHub/esade_fake_news/3_Corona/mikkel's scrapper/data/videos/20200502-111326_coronavirus.json") as json_file:
    data = json.load(json_file)

# %%
#JSON to Pandas Dataframe:

ids = [list(d.keys())[0] for d in data]
flat_data = []
for unique_id in ids:
    flat = dict(data[ids.index(unique_id)][unique_id])
    flat['id'] = unique_id
    flat['recommendations'] = len(flat['recommendations'])
    flat_data.append(flat)
flat_data = pd.DataFrame(flat_data)

# %%
top25 = flat_data[['title','id','channel','genre','key']].groupby(['title','channel','genre','id']).count().sort_values(by='key',ascending=False).head(25)

# %%
# export Data.Frame
top25.to_csv("C:/Users/asf/Documents/GitHub/esade_fake_news/3_Corona/mikkel's scrapper/data/top25/20200503-184010_coronavirus_top25.csv", header=True)

# %%
#Top 25 Videos:
top25
# Out:
#                                                                                                                      key
# title                                              channel                         genre                id
# Full Interview: Edward Snowden On Trump, Privac... MSNBC                           News & Politics      e9yK1QndJSM  170
# NBC Nightly News Broadcast (Full) - May 1st, 20... NBC News                        News & Politics      RE7WYcGJV2I  145
# NBC Nightly News Broadcast (Full) - April 30th,... NBC News                        News & Politics      m6-xtLKxBUc  134
# PBS NewsHour full episode, Apr 30, 2020            PBS NewsHour                    News & Politics      w5QfJ0QiytM   84
# Joe Rogan Experience #1368 - Edward Snowden        PowerfulJRE                     People & Blogs       efs3QRr8LWw   80
# PBS NewsHour full episode, May 1, 2020             PBS NewsHour                    News & Politics      S8AOuKUlH3g   75
# 50 Cent On Trump Pardon For Roger Stone, Biden'... MSNBC                           News & Politics      PzdTBHVwVk8   68
# Exposing Jeffrey Epstein's international sex tr... 60 Minutes Australia            Entertainment        VQOOxOl9l80   67
# Watch CNBC's full interview with Berkshire Hath... CNBC Television                 News & Politics      JvEas_zZ4fM   67
# Krugman: U.S. Almost Surely Headed For Depressi... MSNBC                           News & Politics      H-5YyrUsu5A   64
# Edward Snowden - “Permanent Record” & Life as a... The Daily Show with Trevor Noah Comedy               PArFP7ZJrtg   57
# Live: New York Governor Andrew Cuomo Holds Coro... NBC News                        News & Politics      JF-kpUr-xYA   56
# 🔴 Al Jazeera English | Live                        Al Jazeera English              News & Politics      30qZjexZ8bQ   52
# Joe Rogan Experience #1169 - Elon Musk             PowerfulJRE                     People & Blogs       ycPr5-27vSI   48
# Diana: The Royal Truth                             YouTube Movies                  Movies               ri8YBB5v878   45
# Kushner and Trump Call Coronavirus Response “Su... Late Night with Seth Meyers     Comedy               SQLPqCcs5I4   44
# Global National: April 30, 2020 | Search contin... Global News                     News & Politics      VUnR1FcFU5A   44
# Trump Erupts At Campaign Manager Over Poll Numb... MSNBC                           News & Politics      WCC1R4qSiIw   42
# SNS 300: Spray Welding a Blower Shaft              Abom79                          Science & Technology FLYdhfgF6Pg   40
# How The Economic Machine Works by Ray Dalio        Principles by Ray Dalio         Education            PHe0bXAIuk0   37
# Shields and Brooks on Biden's allegation denial... PBS NewsHour                    News & Politics      1I-upaIVFWQ   37
# Full Interview: 50 Cent On Trump, Oprah, J-Lo, ... MSNBC                           News & Politics      fkthApQs7yo   37
# Joe Rogan Experience #1465 - Tim Pool              PowerfulJRE                     People & Blogs       Cs_mDpIkUOY   35
# The Boy Band Con: The Lou Pearlman Story           YouTube Originals               Film & Animation     CcCRs0Ic3FI   33
# Watch Sky News live                                Sky News                        News & Politics      9Auq9mYxFEE   33

# %%
#top25 videos weight
top25['key'].sum() / len(flat_data)
# Out:
# 0.38925518925518926

# %%
#top25 average - number of videos per unique video
top25['key'].sum() / 25
# Out:
# 63.76

# %%
#Top 25 Channels
top25_channel = flat_data[['channel','key']].groupby(['channel']).count().sort_values(by='key',ascending=False).head(25)

# %%
top25_channel
# Out:
#                                     key
# channel
# MSNBC                               585
# NBC News                            472
# PowerfulJRE                         347
# PBS NewsHour                        255
# 60 Minutes Australia                160
# CNBC Television                     117
# The Daily Show with Trevor Noah     110
# Vincent Racaniello                  105
# YouTube Movies                      101
# The Late Show with Stephen Colbert   91
# Abom79                               83
# Late Night with Seth Meyers          83
# CNN                                  83
# Al Jazeera English                   67
# vpro documentary                     54
# Global News                          51
# BBC News Africa                      49
# Principles by Ray Dalio              45
# DW Documentary                       43
# Sky News                             39
# Democracy Now!                       38
# Yahoo Finance                        35
# Wharton School                       34
# FRANCE 24 English                    33
# YouTube Originals                    33

# %%
#top25_channel channel weight
top25_channel['key'].sum() / len(flat_data)
# Out:
# 0.7601953601953602

# %%
#top25 average - number of videos per unique video
top25_channel['key'].sum() / 25
# Out:
# 124.52

# %%
top25_genre
# Out:
#                        key
# genre
# News & Politics        408
# Entertainment           59
# Comedy                  55
# Education               54
# People & Blogs          48
# Movies                  22
# Science & Technology    16
# Nonprofits & Activism    7
# Music                    4
# Sports                   3
# Travel & Events          2
# Film & Animation         1
# Howto & Style            1

# %%
#top25_genre genre weight
top25_genre['key'].sum() / len(flat_data)
# Out:
# 0.16605616605616605

# %% [markdown]
# ### Coronavirus Conspiracy Search:

# %%
import json
import pandas as pd

with open("C:/Users/asf/Documents/GitHub/esade_fake_news/3_Corona/mikkel's scrapper/data/videos/20200504-170931_covid_19_conspiracy.json") as json_file:
    data = json.load(json_file)

# %%
#JSON to Pandas Dataframe:

ids = [list(d.keys())[0] for d in data]
flat_data = []
for unique_id in ids:
    flat = dict(data[ids.index(unique_id)][unique_id])
    flat['id'] = unique_id
    flat['recommendations'] = len(flat['recommendations'])
    flat_data.append(flat)
flat_data = pd.DataFrame(flat_data)

# %%
#Total Videos:
total_vids = len(flat_data)
total_vids
# Out:
# 7812

# %%
top25 = flat_data[['title','id','channel','genre','key']].groupby(['title','channel','genre','id']).count().sort_values(by='key',ascending=False).head(25)

# %%
# export Data.Frame
top25.to_csv("C:/Users/asf/Documents/GitHub/esade_fake_news/3_Corona/mikkel's scrapper/data/top25/20200503-184010_covid_conspiracy_top25.csv", header=True)

# %%
#Top 25 Videos:
top25
# Out:
#                                                                                                                 key
# title                                              channel                         genre           id
# Coronavirus outbreak: NY Governor Cuomo provide... Global News                     News & Politics ZQYAElmOXEI   34
# LIVE: New York Governor Cuomo delivers update o... Yahoo Finance                   News & Politics 4cGK-iQRrTk   28
# Live: New York Governor Cuomo Holds Coronavirus... NBC News                        News & Politics P0UaGdFvN7Q   25
# New York Gov. Cuomo Delivers COVID-19 Update | ... NowThis News                    News & Politics wwOGS9fLbKw   21
# Coronavirus: New York governor Andrew Cuomo hol... Guardian News                   News & Politics SczCxUdMzPo   20
# Tri-State area governors make joint announcemen... Eyewitness News ABC7NY          News & Politics LBFwWgdsJP4   16
# 'The Dangerous Case Of Donald Trump': 27 Psychi... MSNBC                           News & Politics 6nhoGIvOKJU    9
# PM Justin Trudeau and federal ministers address... Global News                     News & Politics r4RUTHwCfZw    9
# Cuomo Updates on NY Coronavirus Response           NBC New York                    News & Politics IsJ6_5ru8A0    8
# Psychiatrist On ‘The Essential Emptiness Of Pre... MSNBC                           News & Politics 0B4nS1-ScYw    7
# Jordan Klepper vs. Trump Supporters | The Daily... The Daily Show with Trevor Noah Comedy          NzDhm808oU4    7
# Frank Abagnale: "Catch Me If You Can" | Talks a... Talks at Google                 People & Blogs  vsMydMDi3rI    7
# Trump Talk: All Our Best Mashups In One Video      VICE News                       News & Politics 2i4JxWkSYzU    7
# All about Donald Trump’s early years, from trou... PBS NewsHour                    News & Politics rFGE3X6Yhj0    7
# Trump’s Coronavirus Address, Blooper Reel Inclu... The Daily Show with Trevor Noah Comedy          BWO6i8cH8SA    7
# Full Interview: Edward Snowden On Trump, Privac... MSNBC                           News & Politics e9yK1QndJSM    6
# "HEARING IS A JOKE" Democrats MELTDOWN During M... FOX 10 Phoenix                  News & Politics OKifiMcnnek    6
# Live: Michael Gove leads coronavirus daily brie... The Telegraph                   News & Politics f5zukRrgPhk    6
# Joe Rogan Experience #1368 - Edward Snowden        PowerfulJRE                     People & Blogs  efs3QRr8LWw    6
# Psychiatrist On Trump’s ‘Dangerous’ Response To... MSNBC                           News & Politics AKgq0rnIR7g    5
# Watch CNBC's full interview with Berkshire Hath... CNBC Television                 News & Politics JvEas_zZ4fM    5
# Diana: The Royal Truth                             YouTube Movies                  Movies          ri8YBB5v878    5
# Requiem for the American Dream                     YouTube Movies                  Movies          hZnuc-Fv_Tc    5
# Top psychiatrist: Trump's 'mental impairment' p... FRANCE 24 English               News & Politics ghg4-1rEZzk    5
# COVID-19 update: Trudeau addresses Canadians | ... CBC News                        News & Politics QjCtIWEimTk    5

# %%
#top25 videos weight
top25['key'].sum() / len(flat_data)
# Out:
# 0.3911764705882353

# %%
#top25 average - number of videos per unique video
top25['key'].sum() / 25
# Out:
# 10.64

# %%
#Top 25 Channels
top25_channel = flat_data[['channel','key']].groupby(['channel']).count().sort_values(by='key',ascending=False).head(25)

# %%
top25_channel
# Out:
#                                  key
# channel
# Global News                       47
# The Daily Show with Trevor Noah   46
# MSNBC                             42
# NBC News                          32
# Yahoo Finance                     28
# Fox News                          25
# PowerfulJRE                       24
# YouTube Movies                    22
# NowThis News                      21
# Guardian News                     20
# PBS NewsHour                      17
# LastWeekTonight                   16
# Eyewitness News ABC7NY            16
# CBS News                          11
# FRONTLINE PBS | Official          11
# CNBC Television                   11
# DW Documentary                    11
# thechesswebsite                   11
# FRANCE 24 English                  8
# CNN                                8
# NBC New York                       8
# VICE News                          7
# The Telegraph                      7
# Talks at Google                    7
# FOX 10 Phoenix                     7

# %%
#top25_channel channel weight
top25_channel['key'].sum() / len(flat_data)
# Out:
# 0.6808823529411765

# %%
#top25 average - number of videos per unique video
top25_channel['key'].sum() / 25
# Out:
# 18.52

# %%
top25_genre
# Out:
#                        key
# genre
# News & Politics        408
# Entertainment           59
# Comedy                  55
# Education               54
# People & Blogs          48
# Movies                  22
# Science & Technology    16
# Nonprofits & Activism    7
# Music                    4
# Sports                   3
# Travel & Events          2
# Film & Animation         1
# Howto & Style            1

# %%
#top25_genre genre weight
top25_genre['key'].sum() / len(flat_data)
# Out:
# 1.0
