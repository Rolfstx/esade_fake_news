# %%
# convert json to csv
import pandas as pd

df = pd.read_json (r'/Users/Rolf/Documents/GitHub/esade_fake_news/4_Politics/youtube_recommendation_scrapper/data/video-infos-Clinton_v11_d6-Hillary Clinton-20200424.json')

# %%
# transpose DataFrame
# transpose column to rows
df_trans  = df.T

# %%
# drop index and create new index
df_trans_index = df_trans.reset_index(drop=True)

# %%
df_trans_index.head()
# Out:
#       pubdate    views dislikes  likes  \
# 0  2020-04-17  1033301     1205  21180
# 1  2019-11-25  1124288      969  12630
# 2  2018-03-14   198056       44    577
# 3  2020-04-22   115758      131   5337
# 4  2018-05-23  1121585     1193   8480
#
#                                                  key duration           id  \
# 0                   [1fbche, 1hbche, 1ibche, 1jbche]      331  UcvIQJ-QurQ
# 1                                           [1idbge]     2571  CnNwqB0VRSQ
# 2  [1bhjab, 1bhjih, 1ecacb, 1ecaic, 1ecajh, 1ecba...    18691  qFYo6iOL7M4
# 3           [1ejhdg, 1ggfcg, 1gggdg, 1ghhcg, 1ijchg]      183  m5I-Vs_l9Fs
# 4                                   [1idjei, 1jhjei]      443  cm8D4OonKUs
#
#         mult                                              title  \
# 0   0.196236  New Rule: Panic Porn | Real Time with Bill Mah...
# 1  0.0478625  Tres príncipes enfrentados, ¿La nueva guerra d...
# 2     1.3928      2012 Masters Tournament Final Round Broadcast
# ...

# %%
#expand keys into separate rows
#cannot use recommendations column since it is a list
#gives error unhashable type
names = ['pubdate', 'views', 'dislikes', 'likes', 'duration', 'id', 'mult', 'title', 'nb_recommendations', 'depth', 'channel']
idx = pd.MultiIndex.from_tuples(df_trans_index[names].values.tolist(), names=names)
df_long = pd.DataFrame(df_trans_index.key.tolist(), idx).stack().reset_index(names, name='key')

# %%
df_long = (df_trans_index.
           set_index(names).
           key.apply(pd.Series).stack().
           reset_index(names, 
                       name='key')
          )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     354             try:
# --> 355                 codes, categories = factorize(values, sort=True)
#     356             except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     635         codes, uniques = _factorize_array(
# --> 636             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     637         )
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     483     table = hash_klass(size_hint or len(values))
# ...

# %%
df_long.head()
# Out:
#       pubdate    views  dislikes  likes  duration           id      mult  \
# 0  2020-04-17  1033301      1205  21180       331  UcvIQJ-QurQ  0.196236
# 1  2020-04-17  1033301      1205  21180       331  UcvIQJ-QurQ  0.196236
# 2  2020-04-17  1033301      1205  21180       331  UcvIQJ-QurQ  0.196236
# 3  2020-04-17  1033301      1205  21180       331  UcvIQJ-QurQ  0.196236
# 0  2019-11-25  1124288       969  12630      2571  CnNwqB0VRSQ  0.047862
#
#                                                title  nb_recommendations  \
# 0  New Rule: Panic Porn | Real Time with Bill Mah...                  41
# 1  New Rule: Panic Porn | Real Time with Bill Mah...                  41
# 2  New Rule: Panic Porn | Real Time with Bill Mah...                  41
# 3  New Rule: Panic Porn | Real Time with Bill Mah...                  41
# 0  Tres príncipes enfrentados, ¿La nueva guerra d...                  10
#
#    depth                    channel     key
# ...

# %%
# export Data.Frame
export_csv = df_trans_index.to_csv (r'/Users/Rolf/Documents/GitHub/esade_fake_news/4_Politics/youtube_recommendation_scrapper/data/csv/video-infos-20200319_Joe_Biden-Joe Biden-20200319.csv', index = None, header=True)

# %%
# select unique channels
unique_channels = df_trans_index.channel.unique()

# %%
# select unique rows (videos)
unique_rows = df_trans_index.drop_duplicates(subset="id")

# %%
unique_rows
# Out:
#                              channel depth dislikes duration           id key  \
# 0                               CNBC     1      121     1084  MQcPC31KRqA  []
# 1                           NBC News     1       38      641  iyDimnJfT6o  []
# 2                           DoctorOz     2       57      617  9QZLhR__HVQ  []
# 3     U.S. Presidential Inauguration     1       -1     5935  S4VoolvEsyQ  []
# 4                    CNBC Television     1       23      794  bR9SAUEFvHo  []
# 5              The Obama White House     1      845     4843  0UEbEvObgKo  []
# 6              The Obama White House     1     5514     4893  CuzLdMPbKl8  []
# 7                             Forbes     1      112      522  9PMkgtwMkxc  []
# 8                                        1       -1       -1  6LZeYj0y3zM  []
# 9                                Vox     1     2503      322  1UnIDL-eHOs  []
# 10                    DW Documentary     1      812     1709  3K3fy5eKeuM  []
# ...

# %%
unique_channels
# Out:
# array(['CNBC', 'NBC News', 'DoctorOz', 'U.S. Presidential Inauguration',
#        'CNBC Television', 'The Obama White House', 'Forbes', '', 'Vox',
#        'DW Documentary', 'BBC News', 'The Plain Bagel', 'Bloomberg',
#        'ABC News', 'Face PC Gaming', 'LastWeekTonight', 'Syndicado TV',
#        'OfficialHoophall', 'eWomenNetwork, Inc.', 'Fox News', 'The Verge',
#        'NowThis News', 'Washington Post', 'The New York Times',
#        'The Fifth Estate', 'CNN', 'TEDx Talks',
#        'The Daily Show with Trevor Noah', 'Entertainment Weekly',
#        'MsMojo', 'Chromosome8', 'BBC London', 'Charisma on Command',
#        'JRE Clips', 'Nerdwriter1', 'TradingCoachUK', 'Magnificent Cbo',
#        'NFL Films', 'The View', 'Global News', 'CBC News: The National',
#        'Yahoo Finance', 'Matthew Cremona', 'Vincent Racaniello',
#        'News Be Funny', 'ABC News In-depth', "Jay Leno's Garage",
#        'Joseph Vincent', 'The Late Show with Stephen Colbert',
# ...
